# %%
1+1
# Out:
# 2

# %%
x='hello world'
print(x)
# Out:
# hello world

# %%
for i in x:
    print(i)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# # H1

# %% [markdown]
# ## 中文

# %% [markdown]
# ### 中文

# %% [markdown]
# #### 中文

# %% [markdown]
# Inline-style:
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 1")

# %% [markdown]
# Inline-style:
# ![alt text](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1586643443101&di=b628f0fe6d9a4bb2e62f8852fe6c6236&imgtype=0&src=http%3A%2F%2Fa1.att.hoodong.com%2F10%2F16%2F01300000067188120178169763952.jpg "Logo Title Text 1")
